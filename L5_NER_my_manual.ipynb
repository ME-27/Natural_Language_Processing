# %% [markdown]
# # Named Entity Recognition; Working Codes

# %%
import nltk
from nltk.tokenize import word_tokenize
import matplotlib
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
nltk.download('tagsets')
# Out:
# [nltk_data] Downloading package tagsets to
# [nltk_data]     C:\Users\fross\AppData\Roaming\nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!
# True

# %%
nltk.help.upenn_tagset('RB')
nltk.help.upenn_tagset('NN')
nltk.help.upenn_tagset('VB')
# Out:
# RB: adverb
#     occasionally unabatingly maddeningly adventurously professedly
#     stirringly prominently technologically magisterially predominately
#     swiftly fiscally pitilessly ...
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...
# VB: verb, base form
#     ask assemble assess assign assume atone attention avoid bake balkanize
#     bank begin behold believe bend benefit bevel beware bless boil bomb
#     boost brace break bring broil brush build ...

# %%
from nltk.corpus import brown
from nltk.tag import DefaultTagger
from nltk.tag import UnigramTagger
from nltk.tag import BigramTagger, TrigramTagger
from nltk.tag import RegexpTagger

# %%
tags = [tag for (word, tag) in brown.tagged_words(categories='news')]
nltk.FreqDist(tags)
# Out:
# FreqDist({'NN': 13162, 'IN': 10616, 'AT': 8893, 'NP': 6866, ',': 5133, 'NNS': 5066, '.': 4452, 'JJ': 4392, 'CC': 2664, 'VBD': 2524, ...})

# %%
brown_tagged_sents = brown.tagged_sents(categories='news')
train_data = brown_tagged_sents[:int(len(brown_tagged_sents) * 0.9)]  # 90%
test_data = brown_tagged_sents[int(len(brown_tagged_sents) * 0.9):]  # 10%
test_sent = brown.sents(categories='news')[0]
test_data[0]
# Out:
# [('But', 'CC'),
#  ('in', 'IN'),
#  ('all', 'ABN'),
#  ('its', 'PP$'),
#  ('175', 'CD'),
#  ('years', 'NNS'),
#  (',', ','),
#  ('not', '*'),
#  ('a', 'AT'),
#  ('single', 'AP'),
#  ('Negro', 'NP'),
#  ('student', 'NN'),
#  ('has', 'HVZ'),
#  ('entered', 'VBN'),
#  ('its', 'PP$'),
#  ('classrooms', 'NNS'),
#  ('.', '.')]

# %% [markdown]
# ### DefaultTagger

# %%
default_tagger = nltk.DefaultTagger('NN')
display(default_tagger.tag(test_sent), default_tagger.evaluate(test_data))
# Out:
# [('The', 'NN'),
#  ('Fulton', 'NN'),
#  ('County', 'NN'),
#  ('Grand', 'NN'),
#  ('Jury', 'NN'),
#  ('said', 'NN'),
#  ('Friday', 'NN'),
#  ('an', 'NN'),
#  ('investigation', 'NN'),
#  ('of', 'NN'),
#  ("Atlanta's", 'NN'),
#  ('recent', 'NN'),
#  ('primary', 'NN'),
#  ('election', 'NN'),
#  ('produced', 'NN'),
#  ('``', 'NN'),
#  ('no', 'NN'),
#  ('evidence', 'NN'),
#  ("''", 'NN'),
#  ('that', 'NN'),
#  ('any', 'NN'),
#  ('irregularities', 'NN'),
#  ('took', 'NN'),
#  ('place', 'NN'),
#  ('.', 'NN')]
# 0.1262832652247583

# %% [markdown]
# ### UnigramTagger

# %%
unigram_tagger = UnigramTagger(train_data)
display(unigram_tagger.tag(test_sent), unigram_tagger.evaluate(test_data))
# Out:
# [('The', 'AT'),
#  ('Fulton', 'NP-TL'),
#  ('County', 'NN-TL'),
#  ('Grand', 'JJ-TL'),
#  ('Jury', 'NN-TL'),
#  ('said', 'VBD'),
#  ('Friday', 'NR'),
#  ('an', 'AT'),
#  ('investigation', 'NN'),
#  ('of', 'IN'),
#  ("Atlanta's", 'NP$'),
#  ('recent', 'JJ'),
#  ('primary', 'NN'),
#  ('election', 'NN'),
#  ('produced', 'VBD'),
#  ('``', '``'),
#  ('no', 'AT'),
#  ('evidence', 'NN'),
#  ("''", "''"),
#  ('that', 'CS'),
#  ('any', 'DTI'),
#  ('irregularities', 'NNS'),
#  ('took', 'VBD'),
#  ('place', 'NN'),
#  ('.', '.')]
# 0.8121200039868434

# %% [markdown]
# ### BigramTagger

# %%
bigram_tagger = BigramTagger(train_data, backoff=unigram_tagger)
display(bigram_tagger.tag(test_sent), bigram_tagger.evaluate(test_data))
# Out:
# [('The', 'AT'),
#  ('Fulton', 'NP-TL'),
#  ('County', 'NN-TL'),
#  ('Grand', 'JJ-TL'),
#  ('Jury', 'NN-TL'),
#  ('said', 'VBD'),
#  ('Friday', 'NR'),
#  ('an', 'AT'),
#  ('investigation', 'NN'),
#  ('of', 'IN'),
#  ("Atlanta's", 'NP$'),
#  ('recent', 'JJ'),
#  ('primary', 'NN'),
#  ('election', 'NN'),
#  ('produced', 'VBD'),
#  ('``', '``'),
#  ('no', 'AT'),
#  ('evidence', 'NN'),
#  ("''", "''"),
#  ('that', 'CS'),
#  ('any', 'DTI'),
#  ('irregularities', 'NNS'),
#  ('took', 'VBD'),
#  ('place', 'NN'),
#  ('.', '.')]
# 0.8210904016744742

# %% [markdown]
# ### TrigramTagger

# %%
trigram_tagger = TrigramTagger(train_data, backoff=bigram_tagger)
display(trigram_tagger.tag(test_sent), trigram_tagger.evaluate(test_data))
# Out:
# [('The', 'AT'),
#  ('Fulton', 'NP-TL'),
#  ('County', 'NN-TL'),
#  ('Grand', 'JJ-TL'),
#  ('Jury', 'NN-TL'),
#  ('said', 'VBD'),
#  ('Friday', 'NR'),
#  ('an', 'AT'),
#  ('investigation', 'NN'),
#  ('of', 'IN'),
#  ("Atlanta's", 'NP$'),
#  ('recent', 'JJ'),
#  ('primary', 'NN'),
#  ('election', 'NN'),
#  ('produced', 'VBD'),
#  ('``', '``'),
#  ('no', 'AT'),
#  ('evidence', 'NN'),
#  ("''", "''"),
#  ('that', 'CS'),
#  ('any', 'DTI'),
#  ('irregularities', 'NNS'),
#  ('took', 'VBD'),
#  ('place', 'NN'),
#  ('.', '.')]
# 0.8185986245390212

# %% [markdown]
# ### RegexpTagger

# %%
patterns = [
    (r'.*ing$', 'VBG'),                # gerunds
    (r'.*ed$', 'VBD'),                 # simple past
    (r'.*es$', 'VBZ'),                 # 3rd singular present
    (r'.*ould$', 'MD'),                # modals
    (r'.*\'s$', 'NN$'),                # possessive nouns
    (r'.*s$', 'NNS'),                  # plural nouns
    (r'^-?[0-9]+(\.[0-9]+)?$', 'CD'),  # cardinal numbers
    (r'.*', 'NN'),                      # nouns (default) 
    (r'.*ment$', 'NN'),                # i.e. wonderment 
    (r'.*ful$', 'JJ')                  # i.e. wonderful 
]
regexp_tagger = RegexpTagger(patterns)
display(regexp_tagger.tag(test_sent), regexp_tagger.evaluate(test_data))
# Out:
# [('The', 'NN'),
#  ('Fulton', 'NN'),
#  ('County', 'NN'),
#  ('Grand', 'NN'),
#  ('Jury', 'NN'),
#  ('said', 'NN'),
#  ('Friday', 'NN'),
#  ('an', 'NN'),
#  ('investigation', 'NN'),
#  ('of', 'NN'),
#  ("Atlanta's", 'NN$'),
#  ('recent', 'NN'),
#  ('primary', 'NN'),
#  ('election', 'NN'),
#  ('produced', 'VBD'),
#  ('``', 'NN'),
#  ('no', 'NN'),
#  ('evidence', 'NN'),
#  ("''", 'NN'),
#  ('that', 'NN'),
#  ('any', 'NN'),
#  ('irregularities', 'VBZ'),
#  ('took', 'NN'),
#  ('place', 'NN'),
#  ('.', 'NN')]
# 0.20253164556962025

# %% [markdown]
# ### Combination of taggers

# %%
def backoff_tagger(train_sents, tagger_classes, backoff=None):
    for cls in tagger_classes:
        backoff = cls(train_sents, backoff=backoff)
    return backoff


backoff = DefaultTagger('NN') 
tag = backoff_tagger(train_data,  
                     [UnigramTagger, BigramTagger, TrigramTagger],  
                     backoff = backoff) 
  
tag.evaluate(test_data)
# Out:
# 0.843317053722715

# %%
tag.tag(['John'])
# Out:
# [('John', 'NP')]

# %%
from nltk.tag import SequentialBackoffTagger
from nltk.corpus import names

# %%
nltk.download('names')
# Out:
# [nltk_data] Downloading package names to
# [nltk_data]     C:\Users\fross\AppData\Roaming\nltk_data...
# [nltk_data]   Package names is already up-to-date!
# True

# %%
class NamesTagger(SequentialBackoffTagger):
    def __init__(self, *args, **kwargs):
        SequentialBackoffTagger.__init__(self, *args, **kwargs)
        self.name_set = set([n.lower() for n in names.words()])
            
    def choose_tag(self, tokens, index, history):
        word = tokens[index]
        if word.lower() in self.name_set:
             return 'NNP'
        else:
             return None
            
nt = NamesTagger()
print(nt.tag(['Katya'])) 
print(nt.tag(['Adam'])) 
print(nt.tag(['Window']))
# Out:
# [('Katya', 'NNP')]
# [('Adam', 'NNP')]
# [('Window', None)]

# %%
nltk.corpus.brown.tagged_words()
# Out:
# [('The', 'AT'), ('Fulton', 'NP-TL'), ...]

# %%
# nltk.download('universal_tagset')

# %%
nltk.corpus.brown.tagged_words(tagset='universal')
# Out:
# [('The', 'DET'), ('Fulton', 'NOUN'), ...]

# %%
brown_news_tagged = nltk.corpus.brown.tagged_words(categories='adventure', tagset='universal')
tag_fd = nltk.FreqDist(tag for (word, tag) in brown_news_tagged)
tag_fd.most_common()
# Out:
# [('NOUN', 13354),
#  ('VERB', 12274),
#  ('.', 10929),
#  ('DET', 8155),
#  ('ADP', 7069),
#  ('PRON', 5205),
#  ('ADV', 3879),
#  ('ADJ', 3364),
#  ('PRT', 2436),
#  ('CONJ', 2173),
#  ('NUM', 466),
#  ('X', 38)]

# %%
import requests
from bs4 import BeautifulSoup
import re

def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html5lib')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

# document = url_to_string('https://www.nytimes.com/2018/08/13/us/politics/peter-strzok-fired-fbi.html?hp&action=click&pgtype=Homepage&clickSource=story-heading&module=first-column-region&region=top-news&WT.nav=top-news')

document = url_to_string('https://apnews.com/article/new-jersey-newark-city-113055436513a7ac0f1d875cd5913e01?utm_source=homepage&utm_medium=TopNews&utm_campaign=position_04')


nltk.pos_tag(nltk.word_tokenize(document))
# Out:
# [('FBI', 'NNP'),
#  ('warns', 'NNS'),
#  ('of', 'IN'),
#  ("'broad", 'NN'),
#  ("'", 'POS'),
#  ('threat', 'NN'),
#  ('to', 'TO'),
#  ('synagogues', 'VB'),
#  ('in', 'IN'),
#  ('New', 'NNP'),
#  ('Jersey', 'NNP'),
#  ('|', 'NNP'),
#  ('AP', 'NNP'),
#  ('NewsAP', 'NNP'),
#  ('NEWS', 'NNP'),
#  ('ListenSectionsU.S', 'NNP'),
#  ('.', '.'),
#  ('NewsWorld', 'NNP'),
#  ('NewsPoliticsSportsEntertainmentBusinessTechnologyHealthScienceOdditiesLifestylePhotographyVideosListenSectionsAP',
#   'NNP'),
#  ('Top', 'NNP'),
#  ('NewsU.S', 'NNP'),
#  ('.', '.'),
#  ('NewsWorld', 'NNP'),
#  ('NewsAfricaAsia', 'NNP'),
#  ('PacificAustraliaEuropeLatin', 'NNP'),
#  ('AmericaMiddle', 'NNP'),
#  ('EastPoliticsPresident', 'NNP'),
#  ('BidenMidterm', 'NNP'),
#  ('electionsCongressSupreme', 'NN'),
#  ('CourtSportsWorld', 'NNP'),
#  ('SeriesWorld', 'NNP'),
#  ('Cup', 'NNP'),
#  ('2022NFLCollege', 'CD'),
#  ('footballNBANHLEntertainmentFilm', 'NN'),
#  ('ReviewsMoviesMusicTelevisionFashionBusinessU.S', 'NNP'),
#  ('.', '.'),
#  ('economyFinancial', 'JJ'),
#  ('marketsVideosTechnologyHealthCOVID-19MoreScienceAP', 'JJ'),
#  ('Fact', 'NNP'),
#  ('CheckLifestyleReligionPress', 'NNP'),
#  ('ReleasesClimate', 'NNP'),
#  ('and', 'CC'),
#  ('environmentOdditiesPhotographyTravelTrending', 'VBG'),
#  ('NewsMidterm', 'NNP'),
#  ('electionsRussia-Ukraine', 'JJ'),
#  ('warWorld', 'NN'),
#  ('SeriesSearchhttps', 'NNP'),
#  (':', ':'),
#  ('//apnews.com/article/new-jersey-newark-city-113055436513a7ac0f1d875cd5913e01Click',
#   'JJ'),
#  ('to', 'TO'),
#  ('copyhttps', 'VB'),
#  (':', ':'),
#  ('//apnews.com/article/new-jersey-newark-city-113055436513a7ac0f1d875cd5913e01Click',
#   'JJ'),
#  ('to', 'TO'),
#  ('copyRelated', 'VBN'),
#  ('topicsAP', 'NN'),
#  ('Top', 'NNP'),
#  ('NewsU.S', 'NNP'),
#  ('.', '.'),
#  ('NewsReligionNew', 'NNP'),
#  ('JerseyRace', 'NNP'),
#  ('and', 'CC'),
#  ('ethnicityRacial', 'JJ'),
#  ('injusticeNewarkHobokenFBI', 'NN'),
#  ('warns', 'NNS'),
#  ('of', 'IN'),
#  ('‘', 'NNP'),
#  ('broad', 'JJ'),
#  ('’', 'NNP'),
#  ('threat', 'NN'),
#  ('to', 'TO'),
#  ('synagogues', 'VB'),
#  ('in', 'IN'),
#  ('New', 'NNP'),
#  ('JerseyBy', 'NNP'),
#  ('RYAN', 'NNP'),
#  ('KRYSKA', 'NNP'),
#  ('and', 'CC'),
#  ('MICHAEL', 'NNP'),
#  ('BALSAMONovember', 'NNP'),
#  ('4', 'CD'),
#  (',', ','),
#  ('2022', 'CD'),
#  ('GMT1', 'NNP'),
#  ('of', 'IN'),
#  ('2Hoboken', 'CD'),
#  ('Police', 'NNP'),
#  ('officers', 'NNS'),
#  ('stand', 'VBP'),
#  ('watch', 'VB'),
#  ('outside', 'IN'),
#  ('the', 'DT'),
#  ('United', 'NNP'),
#  ('Synagogue', 'NNP'),
#  ('of', 'IN'),
#  ('Hoboken', 'NNP'),
#  (',', ','),
#  ('Thursday', 'NNP'),
#  (',', ','),
#  ('Nov.', 'NNP'),
#  ('3', 'CD'),
#  (',', ','),
#  ('2022', 'CD'),
#  (',', ','),
#  ('in', 'IN'),
#  ('Hoboken', 'NNP'),
#  (',', ','),
#  ('N.J', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('FBI', 'NNP'),
#  ('says', 'VBZ'),
#  ('it', 'PRP'),
#  ('has', 'VBZ'),
#  ('received', 'VBN'),
#  ('credible', 'JJ'),
#  ('information', 'NN'),
#  ('about', 'IN'),
#  ('a', 'DT'),
#  ('threat', 'NN'),
#  ('to', 'TO'),
#  ('synagogues', 'VB'),
#  ('in', 'IN'),
#  ('New', 'NNP'),
#  ('Jersey', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('FBI', 'NNP'),
#  ("'s", 'POS'),
#  ('Newark', 'NNP'),
#  ('office', 'NN'),
#  ('released', 'VBD'),
#  ('a', 'DT'),
#  ('statement', 'NN'),
#  ('Thursday', 'NNP'),
#  ('afternoon', 'NN'),
#  ('that', 'WDT'),
#  ('characterizes', 'VBZ'),
#  ('it', 'PRP'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('broad', 'JJ'),
#  ('threat', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('statement', 'NN'),
#  ('urged', 'VBD'),
#  ('synagogues', 'NNS'),
#  ('to', 'TO'),
#  ('``', '``'),
#  ('take', 'VB'),
#  ('all', 'DT'),
#  ('security', 'NN'),
#  ('precautions', 'NNS'),
#  ('to', 'TO'),
#  ('protect', 'VB'),
#  ('your', 'PRP$'),
#  ('community', 'NN'),
#  ('and', 'CC'),
#  ('facility', 'NN'),
#  ('.', '.'),
#  ('``', '``'),
#  ('(', '('),
#  ('AP', 'NNP'),
#  ('Photo/Ryan', 'NNP'),
#  ('Kryska', 'NNP'),
#  (')', ')'),
#  ('1', 'CD'),
#  ('of', 'IN'),
#  ('2Hoboken', 'CD'),
#  ('Police', 'NNP'),
#  ('officers', 'NNS'),
#  ('stand', 'VBP'),
#  ('watch', 'VB'),
#  ('outside', 'IN'),
#  ('the', 'DT'),
#  ('United', 'NNP'),
#  ('Synagogue', 'NNP'),
#  ('of', 'IN'),
#  ('Hoboken', 'NNP'),
#  (',', ','),
#  ('Thursday', 'NNP'),
#  (',', ','),
#  ('Nov.', 'NNP'),
#  ('3', 'CD'),
#  (',', ','),
#  ('2022', 'CD'),
#  (',', ','),
#  ('in', 'IN'),
#  ('Hoboken', 'NNP'),
#  (',', ','),
#  ('N.J', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('FBI', 'NNP'),
#  ('says', 'VBZ'),
#  ('it', 'PRP'),
#  ('has', 'VBZ'),
#  ('received', 'VBN'),
#  ('credible', 'JJ'),
#  ('information', 'NN'),
#  ('about', 'IN'),
#  ('a', 'DT'),
#  ('threat', 'NN'),
#  ('to', 'TO'),
#  ('synagogues', 'VB'),
#  ('in', 'IN'),
#  ('New', 'NNP'),
#  ('Jersey', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('FBI', 'NNP'),
#  ("'s", 'POS'),
#  ('Newark', 'NNP'),
#  ('office', 'NN'),
#  ('released', 'VBD'),
#  ('a', 'DT'),
#  ('statement', 'NN'),
#  ('Thursday', 'NNP'),
#  ('afternoon', 'NN'),
#  ('that', 'WDT'),
#  ('characterizes', 'VBZ'),
#  ('it', 'PRP'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('broad', 'JJ'),
#  ('threat', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('statement', 'NN'),
#  ('urged', 'VBD'),
#  ('synagogues', 'NNS'),
#  ('to', 'TO'),
#  ('``', '``'),
#  ('take', 'VB'),
#  ('all', 'DT'),
#  ('security', 'NN'),
#  ('precautions', 'NNS'),
#  ('to', 'TO'),
#  ('protect', 'VB'),
#  ('your', 'PRP$'),
#  ('community', 'NN'),
#  ('and', 'CC'),
#  ('facility', 'NN'),
#  ('.', '.'),
#  ('``', '``'),
#  ('(', '('),
#  ('AP', 'NNP'),
#  ('Photo/Ryan', 'NNP'),
#  ('Kryska', 'NNP'),
#  (')', ')'),
#  ('HOBOKEN', 'NNP'),
#  (',', ','),
#  ('N.J.', 'NNP'),
#  ('(', '('),
#  ('AP', 'NNP'),
#  (')', ')'),
#  ('—', 'VBD'),
#  ('The', 'DT'),
#  ('FBI', 'NNP'),
#  ('said', 'VBD'),
#  ('Thursday', 'NNP'),
#  ('that', 'IN'),
#  ('it', 'PRP'),
#  ('had', 'VBD'),
#  ('received', 'VBN'),
#  ('credible', 'JJ'),
#  ('information', 'NN'),
#  ('about', 'IN'),
#  ('a', 'DT'),
#  ('“', 'JJ'),
#  ('broad', 'JJ'),
#  ('”', 'NN'),
#  ('threat', 'NN'),
#  ('to', 'TO'),
#  ('synagogues', 'VB'),
#  ('in', 'IN'),
#  ('New', 'NNP'),
#  ('Jersey', 'NNP'),
#  (',', ','),
#  ('a', 'DT'),
#  ('warning', 'NN'),
#  ('that', 'WDT'),
#  ('prompted', 'VBD'),
#  ('some', 'DT'),
#  ('municipalities', 'NNS'),
#  ('to', 'TO'),
#  ('send', 'VB'),
#  ('extra', 'JJ'),
#  ('police', 'NN'),
#  ('officers', 'NNS'),
#  ('to', 'TO'),
#  ('guard', 'VB'),
#  ('houses', 'NNS'),
#  ('of', 'IN'),
#  ('worship.The', 'JJ'),
#  ('nature', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('threat', 'NN'),
#  ('was', 'VBD'),
#  ('vague', 'JJ'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('FBI', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('Newark', 'NNP'),
#  ('office', 'NN'),
#  ('released', 'VBD'),
#  ('a', 'DT'),
#  ('statement', 'NN'),
#  ('urging', 'VBG'),
#  ('synagogues', 'NNS'),
#  ('to', 'TO'),
#  ('“', 'VB'),
#  ('take', 'VB'),
#  ('all', 'DT'),
#  ('security', 'NN'),
#  ('precautions', 'NNS'),
#  ('to', 'TO'),
#  ('protect', 'VB'),
#  ('your', 'PRP$'),
#  ('community', 'NN'),
#  ('and', 'CC'),
#  ('facility', 'NN'),
#  (',', ','),
#  ('”', 'NNP'),
#  ('but', 'CC'),
#  ('wouldn', 'JJ'),
#  ('’', 'JJ'),
#  ('t', 'NNS'),
#  ('say', 'VBP'),
#  ('anything', 'NN'),
#  ('about', 'IN'),
#  ('who', 'WP'),
#  ('made', 'VBD'),
#  ('the', 'DT'),
#  ('threat', 'NN'),
#  ('or', 'CC'),
#  ('why.The', 'NN'),
#  ('alert', 'NN'),
#  ('was', 'VBD'),
#  ('posted', 'VBN'),
#  ('after', 'IN'),
#  ('officials', 'NNS'),
#  ('discovered', 'VBD'),
#  ('an', 'DT'),
#  ('online', 'JJ'),
#  ('threat', 'NN'),
#  ('directed', 'VBD'),
#  ('broadly', 'RB'),
#  ('at', 'IN'),
#  ('synagogues', 'NNS'),
#  ('in', 'IN'),
#  ('New', 'NNP'),
#  ('Jersey', 'NNP'),
#  (',', ','),
#  ('a', 'DT'),
#  ('law', 'NN'),
#  ('enforcement', 'NN'),
#  ('official', 'NN'),
#  ('said', 'VBD'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('posting', 'VBG'),
#  ('did', 'VBD'),
#  ('not', 'RB'),
#  ('target', 'VB'),
#  ('any', 'DT'),
#  ('specific', 'JJ'),
#  ('synagogue', 'NN'),
#  ('by', 'IN'),
#  ('name', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('official', 'NN'),
#  ('said', 'VBD'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('official', 'NN'),
#  ('could', 'MD'),
#  ('not', 'RB'),
#  ('discuss', 'VB'),
#  ('details', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('investigation', 'NN'),
#  ('publicly', 'RB'),
#  ('and', 'CC'),
#  ('spoke', 'VBD'),
#  ('to', 'TO'),
#  ('The', 'DT'),
#  ('Associated', 'NNP'),
#  ('Press', 'NNP'),
#  ('on', 'IN'),
#  ('condition', 'NN'),
#  ('of', 'IN'),
#  ('anonymity.Messages', 'NNS'),
#  ('left', 'VBN'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('FBI', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('Newark', 'NNP'),
#  ('office', 'NN'),
#  ('weren', 'NN'),
#  ('’', 'VBP'),
#  ('t', 'JJ'),
#  ('returned.Public', 'JJ'),
#  ('warnings', 'NNS'),
#  ('about', 'IN'),
#  ('nonspecific', 'JJ'),
#  ('threats', 'NNS'),
#  ('against', 'IN'),
#  ('Jewish', 'JJ'),
#  ('institutions', 'NNS'),
#  (',', ','),
#  ('made', 'VBN'),
#  ('by', 'IN'),
#  ('a', 'DT'),
#  ('variety', 'NN'),
#  ('of', 'IN'),
#  ('groups', 'NNS'),
#  ('including', 'VBG'),
#  ('Christian', 'JJ'),
#  ('supremacists', 'NNS'),
#  ('and', 'CC'),
#  ('Islamist', 'NNP'),
#  ('extremists', 'NNS'),
#  (',', ','),
#  ('aren', 'NNS'),
#  ('’', 'VBP'),
#  ('t', 'JJ'),
#  ('unusual', 'JJ'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('New', 'NNP'),
#  ('York', 'NNP'),
#  ('City', 'NNP'),
#  ('metropolitan', 'JJ'),
#  ('area', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('many', 'JJ'),
#  ('turn', 'VBP'),
#  ('out', 'RP'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('false', 'JJ'),
#  ('alarms', 'NNS'),
#  ('.', '.'),
#  ('But', 'CC'),
#  ('the', 'DT'),
#  ('area', 'NN'),
#  ('has', 'VBZ'),
#  ('also', 'RB'),
#  ('seen', 'VBN'),
#  ('deadly', 'RB'),
#  ('attacks.ADVERTISEMENTIn', 'JJ'),
#  ('Jersey', 'NNP'),
#  ('City', 'NNP'),
#  (',', ','),
#  ('Mayor', 'NNP'),
#  ('Steven', 'NNP'),
#  ('Fulop', 'NNP'),
#  ('said', 'VBD'),
#  ('police', 'NNS'),
#  ('would', 'MD'),
#  ('be', 'VB'),
#  ('posted', 'VBN'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('city', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('seven', 'CD'),
#  ('synagogues', 'NNS'),
#  ('and', 'CC'),
#  ('foot', 'NN'),
#  ('patrols', 'NNS'),
#  ('would', 'MD'),
#  ('be', 'VB'),
#  ('added', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('broader', 'JJR'),
#  ('Jewish', 'NNP'),
#  ('community', 'NN'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('2019', 'CD'),
#  (',', ','),
#  ('two', 'CD'),
#  ('assailants', 'NNS'),
#  ('motivated', 'VBN'),
#  ('by', 'IN'),
#  ('anti-Jewish', 'JJ'),
#  ('hate', 'NN'),
#  ('killed', 'VBD'),
#  ('a', 'DT'),
#  ('police', 'NN'),
#  ('officer', 'NN'),
#  (',', ','),
#  ('then', 'RB'),
#  ('drove', 'VB'),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('kosher', 'NN'),
#  ('market', 'NN'),
#  ('in', 'IN'),
#  ('Jersey', 'NNP'),
#  ('City', 'NNP'),
#  ('and', 'CC'),
#  ('killed', 'VBD'),
#  ('three', 'CD'),
#  ('more', 'JJR'),
#  ('people', 'NNS'),
#  (',', ','),
#  ('before', 'IN'),
#  ('being', 'VBG'),
#  ('slain', 'VBN'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('gunbattle', 'NN'),
#  ('with', 'IN'),
#  ('police.ReligionPope', 'NN'),
#  ('tells', 'NNS'),
#  ('Bahrain', 'VBP'),
#  ('youths', 'NNS'),
#  ('to', 'TO'),
#  ('seek', 'VB'),
#  ('real', 'JJ'),
#  ('advice', 'NN'),
#  (',', ','),
#  ('not', 'RB'),
#  ('GoogleKosovo', 'NNP'),
#  ("'s", 'POS'),
#  ('ethnic', 'JJ'),
#  ('Serb', 'NNP'),
#  ('police', 'NNS'),
#  (',', ','),
#  ('lawmakers', 'NNS'),
#  ('resign', 'VBP'),
#  ('en', 'JJ'),
#  ('masseWalker', 'NN'),
#  (',', ','),
#  ('Warnock', 'NNP'),
#  ('offer', 'VBP'),
#  ('clashing', 'VBG'),
#  ('religious', 'JJ'),
#  ('messages', 'NNS'),
#  ('in', 'IN'),
#  ('GeorgiaPrivate', 'NNP'),
#  ('school', 'NN'),
#  ('vouchers', 'NNS'),
#  ('open', 'VBP'),
#  ('faith', 'NN'),
#  ('options', 'NNS'),
#  ('for', 'IN'),
#  ('kids', 'NNS'),
#  ('of', 'IN'),
#  ('colorPolice', 'NN'),
#  ('officers', 'NNS'),
#  ('armed', 'VBD'),
#  ('with', 'IN'),
#  ('rifles', 'NNS'),
#  ('guarded', 'VBD'),
#  ('a', 'DT'),
#  ('synagogue', 'JJ'),
#  ('one', 'CD'),
#  ('city', 'NN'),
#  ('over', 'IN'),
#  (',', ','),
#  ('in', 'IN'),
#  ('Hoboken', 'NNP'),
#  (',', ','),
#  ('where', 'WRB'),
#  ('the', 'DT'),
#  ('public', 'JJ'),
#  ('safety', 'NN'),
#  ('director', 'NN'),
#  ('also', 'RB'),
#  ('announced', 'VBD'),
#  ('increased', 'JJ'),
#  ('patrols', 'NNS'),
#  ('in', 'IN'),
#  ('Jewish', 'JJ'),
#  ('communities.Five', 'CD'),
#  ('years', 'NNS'),
#  ('ago', 'RB'),
#  (',', ','),
#  ('two', 'CD'),
#  ('New', 'NNP'),
#  ('Jersey', 'NNP'),
#  ('men', 'NNS'),
#  ('were', 'VBD'),
#  ('sentenced', 'VBN'),
#  ('to', 'TO'),
#  ('35', 'CD'),
#  ('years', 'NNS'),
#  ('in', 'IN'),
#  ('prison', 'NN'),
#  ('after', 'IN'),
#  ('being', 'VBG'),
#  ('convicted', 'VBN'),
#  ('for', 'IN'),
#  ('a', 'DT'),
#  ('series', 'NN'),
#  ('of', 'IN'),
#  ('attacks', 'NNS'),
#  ('in', 'IN'),
#  ('2012', 'CD'),
#  ('that', 'WDT'),
#  ('included', 'VBD'),
#  ('the', 'DT'),
#  ('firebombings', 'NNS'),
#  ('of', 'IN'),
#  ('two', 'CD'),
#  ('synagogues', 'NNS'),
#  ('.', '.'),
#  ('They', 'PRP'),
#  ('also', 'RB'),
#  ('threw', 'VBD'),
#  ('a', 'DT'),
#  ('Molotov', 'NNP'),
#  ('cocktail', 'NN'),
#  ('into', 'IN'),
#  ('the', 'DT'),
#  ('home', 'NN'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('rabbi', 'NN'),
#  ('as', 'IN'),
#  ('he', 'PRP'),
#  ('slept', 'VBD'),
#  ('with', 'IN'),
#  ('his', 'PRP$'),
#  ('wife', 'NN'),
#  ('and', 'CC'),
#  ('children.In', 'NN'),
#  ('2019', 'CD'),
#  (',', ','),
#  ('a', 'DT'),
#  ('man', 'NN'),
#  ('stabbed', 'VBD'),
#  ('five', 'CD'),
#  ('people', 'NNS'),
#  ('at', 'IN'),
#  ('a', 'DT'),
#  ('Hanukkah', 'NNP'),
#  ('celebration', 'NN'),
#  ('at', 'IN'),
#  ('a', 'DT'),
#  ('rabbi', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('home', 'NN'),
#  ('in', 'IN'),
#  ('an', 'DT'),
#  ('Orthodox', 'NNP'),
#  ('Jewish', 'NNP'),
#  ('community', 'NN'),
#  ('north', 'NN'),
#  ('of', 'IN'),
#  ('New', 'NNP'),
#  ('York', 'NNP'),
#  ('City', 'NNP'),
#  (',', ','),
#  ('fatally', 'RB'),
#  ('wounding', 'VBG'),
#  ('one', 'CD'),
#  ('person.U.S', 'NN'),
#  ('.', '.'),
#  ('Rep.', 'NNP'),
#  ('Josh', 'NNP'),
#  ('Gottheimer', 'NNP'),
#  (',', ','),
#  ('a', 'DT'),
#  ('New', 'NNP'),
#  ('Jersey', 'NNP'),
#  ('Democrat', 'NNP'),
#  (',', ','),
#  ('said', 'VBD'),
#  ('he', 'PRP'),
#  ('was', 'VBD'),
#  ('“', 'JJ'),
#  ('concerned', 'JJ'),
#  ('and', 'CC'),
#  ('outraged', 'VBN'),
#  ('”', 'NN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('latest', 'JJS'),
#  ('threat', 'NN'),
#  ('against', 'IN'),
#  ('Jews.ADVERTISEMENT', 'NNP'),
#  ('“', 'NNP'),
#  ('I', 'PRP'),
#  ('am', 'VBP'),
#  ('deeply', 'RB'),
#  ('concerned', 'JJ'),
#  ('and', 'CC'),
#  ('outraged', 'VBN'),
#  ('by', 'IN'),
#  ('today', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'NN'),
#  ('alert', 'NN'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('FBI', 'NNP'),
#  (',', ','),
#  ('”', 'NNP'),
#  ('Gottheimer', 'NNP'),
#  ('said', 'VBD'),
#  ('.', '.'),
#  ('“', 'NN'),
#  ('This', 'DT'),
#  ('is', 'VBZ'),
#  ('what', 'WP'),
#  ('happens', 'VBZ'),
#  ('after', 'IN'),
#  ('years', 'NNS'),
#  ('of', 'IN'),
#  ('antisemitic', 'JJ'),
#  ('comments', 'NNS'),
#  ('from', 'IN'),
#  ('public', 'JJ'),
#  ('figures', 'NNS'),
#  (',', ','),
#  ('”', 'CC'),
#  ('he', 'PRP'),
#  ('added', 'VBD'),
#  (',', ','),
#  ('citing', 'VBG'),
#  ('recent', 'JJ'),
#  ('comments', 'NNS'),
#  ('by', 'IN'),
#  ('Kanye', 'NNP'),
#  ('West', 'NNP'),
#  ('and', 'CC'),
#  ('a', 'DT'),
#  ('social', 'JJ'),
#  ('media', 'NNS'),
#  ('post', 'NN'),
#  ('shared', 'VBN'),
#  ('by', 'IN'),
#  ('NBA', 'NNP'),
#  ('star', 'NN'),
#  ('Kyrie', 'NNP'),
#  ('Irving.The', 'NNP'),
#  ('FBI', 'NNP'),
#  ('didn', 'NN'),
#  ('’', 'NNP'),
#  ('t', 'NN'),
#  ('release', 'NN'),
#  ('any', 'DT'),
#  ('information', 'NN'),
#  ('suggesting', 'VBG'),
#  ('the', 'DT'),
#  ('threat', 'NN'),
#  ('that', 'WDT'),
#  ('prompted', 'VBD'),
#  ('the', 'DT'),
#  ('warning', 'NN'),
#  ('was', 'VBD'),
#  ('related', 'VBN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('public', 'JJ'),
#  ('debate', 'NN'),
#  ('over', 'IN'),
#  ('those', 'DT'),
#  ('comments.___Balsamo', 'NNS'),
#  ('reported', 'VBN'),
#  ('from', 'IN'),
#  ('Washington', 'NNP'),
#  ('.', '.'),
#  ('Associated', 'NNP'),
#  ('Press', 'NNP'),
#  ('writer', 'NN'),
#  ('David', 'NNP'),
#  ('Porter', 'NNP'),
#  ('contributed', 'VBD'),
#  ('to', 'TO'),
#  ('this', 'DT'),
#  ('report.AP', 'NN'),
#  ('NEWSTop', 'NNP'),
#  ('StoriesVideoContact', 'NNP'),
#  ('UsAccessibility', 'NNP'),
#  ('StatementCookie', 'NNP'),
#  ('SettingsDownload', 'NNP'),
#  ('AP', 'NNP'),
#  ('NEWSConnect', 'NNP'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('definitive', 'JJ'),
#  ('source', 'NN'),
#  ('for', 'IN'),
#  ('global', 'JJ'),
#  ('and', 'CC'),
#  ('local', 'JJ'),
#  ('newsMore', 'NN'),
#  ('from', 'IN'),
#  ('APap.orgAP', 'NNP'),
#  ('InsightsAP', 'NNP'),
#  ('Definitive', 'NNP'),
#  ('Source', 'NNP'),
#  ('BlogAP', 'NNP'),
#  ('Images', 'NNP'),
#  ('SpotlightAP', 'NNP'),
#  ('ExploreAP', 'NNP'),
#  ('BooksAP', 'NNP'),
#  ('StylebookFollow', 'NNP'),
#  ('APThe', 'NNP'),
#  ('Associated', 'NNP'),
#  ('PressAboutContactCustomer', 'NNP'),
#  ('SupportCareersTerms', 'NNP'),
#  ('&', 'CC'),
#  ('ConditionsPrivacyAll', 'NNP'),
#  ('contents', 'VBZ'),
#  ('©', 'VB'),
#  ('copyright', 'JJ'),
#  ('2022', 'CD'),
#  ('The', 'DT'),
#  ('Associated', 'NNP'),
#  ('Press', 'NNP'),
#  ('.', '.'),
#  ('All', 'NNP'),
#  ('rights', 'NNS'),
#  ('reserved', 'VBN'),
#  ('.', '.')]

# %%
{(' '.join(c[0] for c in chunk), chunk.label() ) for chunk in nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(document))) if hasattr(chunk, 'label') }
# Out:
# {('AP', 'ORGANIZATION'),
#  ('Associated', 'ORGANIZATION'),
#  ('Associated Press', 'ORGANIZATION'),
#  ('CheckLifestyleReligionPress', 'ORGANIZATION'),
#  ('Christian', 'GPE'),
#  ('ConditionsPrivacyAll', 'ORGANIZATION'),
#  ('CourtSportsWorld', 'ORGANIZATION'),
#  ('David Porter', 'PERSON'),
#  ('FBI', 'ORGANIZATION'),
#  ('GeorgiaPrivate', 'ORGANIZATION'),
#  ('GoogleKosovo', 'ORGANIZATION'),
#  ('Gottheimer', 'PERSON'),
#  ('HOBOKEN', 'ORGANIZATION'),
#  ('Hoboken', 'GPE'),
#  ('Islamist', 'ORGANIZATION'),
#  ('Jersey', 'PERSON'),
#  ('Jersey City', 'GPE'),
#  ('Jersey City', 'PERSON'),
#  ('Jersey Democrat', 'PERSON'),
#  ('JerseyBy', 'ORGANIZATION'),
#  ('Jewish', 'GPE'),
#  ('Kanye West', 'PERSON'),
#  ('Kyrie', 'PERSON'),
#  ('MICHAEL', 'ORGANIZATION'),
#  ('Mayor Steven Fulop', 'PERSON'),
#  ('Molotov', 'GPE'),
#  ('N.J.', 'GPE'),
#  ('NBA', 'ORGANIZATION'),
#  ('NEWSTop', 'ORGANIZATION'),
#  ('New', 'GPE'),
#  ('New Jersey', 'GPE'),
#  ('New York City', 'GPE'),
#  ('Newark', 'GPE'),
#  ('NewsAP', 'ORGANIZATION'),
#  ('NewsMidterm', 'ORGANIZATION'),
#  ('NewsReligionNew', 'ORGANIZATION'),
#  ('NewsWorld', 'ORGANIZATION'),
#  ('Serb', 'GPE'),
#  ('Source BlogAP Images', 'PERSON'),
#  ('United Synagogue', 'ORGANIZATION'),
#  ('Warnock', 'GPE'),
#  ('Washington', 'GPE'),
#  ('colorPolice', 'ORGANIZATION'),
#  ('ethnicityRacial', 'ORGANIZATION'),
#  ('footballNBANHLEntertainmentFilm', 'ORGANIZATION'),
#  ('injusticeNewarkHobokenFBI', 'ORGANIZATION'),
#  ('masseWalker', 'ORGANIZATION'),
#  ('newsMore', 'ORGANIZATION'),
#  ('topicsAP Top', 'ORGANIZATION'),
#  ('warWorld', 'ORGANIZATION')}

# %%
nltk.pos_tag(nltk.word_tokenize(document))
# Out:
# [('FBI', 'NNP'),
#  ('warns', 'NNS'),
#  ('of', 'IN'),
#  ("'broad", 'NN'),
#  ("'", 'POS'),
#  ('threat', 'NN'),
#  ('to', 'TO'),
#  ('synagogues', 'VB'),
#  ('in', 'IN'),
#  ('New', 'NNP'),
#  ('Jersey', 'NNP'),
#  ('|', 'NNP'),
#  ('AP', 'NNP'),
#  ('NewsAP', 'NNP'),
#  ('NEWS', 'NNP'),
#  ('ListenSectionsU.S', 'NNP'),
#  ('.', '.'),
#  ('NewsWorld', 'NNP'),
#  ('NewsPoliticsSportsEntertainmentBusinessTechnologyHealthScienceOdditiesLifestylePhotographyVideosListenSectionsAP',
#   'NNP'),
#  ('Top', 'NNP'),
#  ('NewsU.S', 'NNP'),
#  ('.', '.'),
#  ('NewsWorld', 'NNP'),
#  ('NewsAfricaAsia', 'NNP'),
#  ('PacificAustraliaEuropeLatin', 'NNP'),
#  ('AmericaMiddle', 'NNP'),
#  ('EastPoliticsPresident', 'NNP'),
#  ('BidenMidterm', 'NNP'),
#  ('electionsCongressSupreme', 'NN'),
#  ('CourtSportsWorld', 'NNP'),
#  ('SeriesWorld', 'NNP'),
#  ('Cup', 'NNP'),
#  ('2022NFLCollege', 'CD'),
#  ('footballNBANHLEntertainmentFilm', 'NN'),
#  ('ReviewsMoviesMusicTelevisionFashionBusinessU.S', 'NNP'),
#  ('.', '.'),
#  ('economyFinancial', 'JJ'),
#  ('marketsVideosTechnologyHealthCOVID-19MoreScienceAP', 'JJ'),
#  ('Fact', 'NNP'),
#  ('CheckLifestyleReligionPress', 'NNP'),
#  ('ReleasesClimate', 'NNP'),
#  ('and', 'CC'),
#  ('environmentOdditiesPhotographyTravelTrending', 'VBG'),
#  ('NewsMidterm', 'NNP'),
#  ('electionsRussia-Ukraine', 'JJ'),
#  ('warWorld', 'NN'),
#  ('SeriesSearchhttps', 'NNP'),
#  (':', ':'),
#  ('//apnews.com/article/new-jersey-newark-city-113055436513a7ac0f1d875cd5913e01Click',
#   'JJ'),
#  ('to', 'TO'),
#  ('copyhttps', 'VB'),
#  (':', ':'),
#  ('//apnews.com/article/new-jersey-newark-city-113055436513a7ac0f1d875cd5913e01Click',
#   'JJ'),
#  ('to', 'TO'),
#  ('copyRelated', 'VBN'),
#  ('topicsAP', 'NN'),
#  ('Top', 'NNP'),
#  ('NewsU.S', 'NNP'),
#  ('.', '.'),
#  ('NewsReligionNew', 'NNP'),
#  ('JerseyRace', 'NNP'),
#  ('and', 'CC'),
#  ('ethnicityRacial', 'JJ'),
#  ('injusticeNewarkHobokenFBI', 'NN'),
#  ('warns', 'NNS'),
#  ('of', 'IN'),
#  ('‘', 'NNP'),
#  ('broad', 'JJ'),
#  ('’', 'NNP'),
#  ('threat', 'NN'),
#  ('to', 'TO'),
#  ('synagogues', 'VB'),
#  ('in', 'IN'),
#  ('New', 'NNP'),
#  ('JerseyBy', 'NNP'),
#  ('RYAN', 'NNP'),
#  ('KRYSKA', 'NNP'),
#  ('and', 'CC'),
#  ('MICHAEL', 'NNP'),
#  ('BALSAMONovember', 'NNP'),
#  ('4', 'CD'),
#  (',', ','),
#  ('2022', 'CD'),
#  ('GMT1', 'NNP'),
#  ('of', 'IN'),
#  ('2Hoboken', 'CD'),
#  ('Police', 'NNP'),
#  ('officers', 'NNS'),
#  ('stand', 'VBP'),
#  ('watch', 'VB'),
#  ('outside', 'IN'),
#  ('the', 'DT'),
#  ('United', 'NNP'),
#  ('Synagogue', 'NNP'),
#  ('of', 'IN'),
#  ('Hoboken', 'NNP'),
#  (',', ','),
#  ('Thursday', 'NNP'),
#  (',', ','),
#  ('Nov.', 'NNP'),
#  ('3', 'CD'),
#  (',', ','),
#  ('2022', 'CD'),
#  (',', ','),
#  ('in', 'IN'),
#  ('Hoboken', 'NNP'),
#  (',', ','),
#  ('N.J', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('FBI', 'NNP'),
#  ('says', 'VBZ'),
#  ('it', 'PRP'),
#  ('has', 'VBZ'),
#  ('received', 'VBN'),
#  ('credible', 'JJ'),
#  ('information', 'NN'),
#  ('about', 'IN'),
#  ('a', 'DT'),
#  ('threat', 'NN'),
#  ('to', 'TO'),
#  ('synagogues', 'VB'),
#  ('in', 'IN'),
#  ('New', 'NNP'),
#  ('Jersey', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('FBI', 'NNP'),
#  ("'s", 'POS'),
#  ('Newark', 'NNP'),
#  ('office', 'NN'),
#  ('released', 'VBD'),
#  ('a', 'DT'),
#  ('statement', 'NN'),
#  ('Thursday', 'NNP'),
#  ('afternoon', 'NN'),
#  ('that', 'WDT'),
#  ('characterizes', 'VBZ'),
#  ('it', 'PRP'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('broad', 'JJ'),
#  ('threat', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('statement', 'NN'),
#  ('urged', 'VBD'),
#  ('synagogues', 'NNS'),
#  ('to', 'TO'),
#  ('``', '``'),
#  ('take', 'VB'),
#  ('all', 'DT'),
#  ('security', 'NN'),
#  ('precautions', 'NNS'),
#  ('to', 'TO'),
#  ('protect', 'VB'),
#  ('your', 'PRP$'),
#  ('community', 'NN'),
#  ('and', 'CC'),
#  ('facility', 'NN'),
#  ('.', '.'),
#  ('``', '``'),
#  ('(', '('),
#  ('AP', 'NNP'),
#  ('Photo/Ryan', 'NNP'),
#  ('Kryska', 'NNP'),
#  (')', ')'),
#  ('1', 'CD'),
#  ('of', 'IN'),
#  ('2Hoboken', 'CD'),
#  ('Police', 'NNP'),
#  ('officers', 'NNS'),
#  ('stand', 'VBP'),
#  ('watch', 'VB'),
#  ('outside', 'IN'),
#  ('the', 'DT'),
#  ('United', 'NNP'),
#  ('Synagogue', 'NNP'),
#  ('of', 'IN'),
#  ('Hoboken', 'NNP'),
#  (',', ','),
#  ('Thursday', 'NNP'),
#  (',', ','),
#  ('Nov.', 'NNP'),
#  ('3', 'CD'),
#  (',', ','),
#  ('2022', 'CD'),
#  (',', ','),
#  ('in', 'IN'),
#  ('Hoboken', 'NNP'),
#  (',', ','),
#  ('N.J', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('FBI', 'NNP'),
#  ('says', 'VBZ'),
#  ('it', 'PRP'),
#  ('has', 'VBZ'),
#  ('received', 'VBN'),
#  ('credible', 'JJ'),
#  ('information', 'NN'),
#  ('about', 'IN'),
#  ('a', 'DT'),
#  ('threat', 'NN'),
#  ('to', 'TO'),
#  ('synagogues', 'VB'),
#  ('in', 'IN'),
#  ('New', 'NNP'),
#  ('Jersey', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('FBI', 'NNP'),
#  ("'s", 'POS'),
#  ('Newark', 'NNP'),
#  ('office', 'NN'),
#  ('released', 'VBD'),
#  ('a', 'DT'),
#  ('statement', 'NN'),
#  ('Thursday', 'NNP'),
#  ('afternoon', 'NN'),
#  ('that', 'WDT'),
#  ('characterizes', 'VBZ'),
#  ('it', 'PRP'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('broad', 'JJ'),
#  ('threat', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('statement', 'NN'),
#  ('urged', 'VBD'),
#  ('synagogues', 'NNS'),
#  ('to', 'TO'),
#  ('``', '``'),
#  ('take', 'VB'),
#  ('all', 'DT'),
#  ('security', 'NN'),
#  ('precautions', 'NNS'),
#  ('to', 'TO'),
#  ('protect', 'VB'),
#  ('your', 'PRP$'),
#  ('community', 'NN'),
#  ('and', 'CC'),
#  ('facility', 'NN'),
#  ('.', '.'),
#  ('``', '``'),
#  ('(', '('),
#  ('AP', 'NNP'),
#  ('Photo/Ryan', 'NNP'),
#  ('Kryska', 'NNP'),
#  (')', ')'),
#  ('HOBOKEN', 'NNP'),
#  (',', ','),
#  ('N.J.', 'NNP'),
#  ('(', '('),
#  ('AP', 'NNP'),
#  (')', ')'),
#  ('—', 'VBD'),
#  ('The', 'DT'),
#  ('FBI', 'NNP'),
#  ('said', 'VBD'),
#  ('Thursday', 'NNP'),
#  ('that', 'IN'),
#  ('it', 'PRP'),
#  ('had', 'VBD'),
#  ('received', 'VBN'),
#  ('credible', 'JJ'),
#  ('information', 'NN'),
#  ('about', 'IN'),
#  ('a', 'DT'),
#  ('“', 'JJ'),
#  ('broad', 'JJ'),
#  ('”', 'NN'),
#  ('threat', 'NN'),
#  ('to', 'TO'),
#  ('synagogues', 'VB'),
#  ('in', 'IN'),
#  ('New', 'NNP'),
#  ('Jersey', 'NNP'),
#  (',', ','),
#  ('a', 'DT'),
#  ('warning', 'NN'),
#  ('that', 'WDT'),
#  ('prompted', 'VBD'),
#  ('some', 'DT'),
#  ('municipalities', 'NNS'),
#  ('to', 'TO'),
#  ('send', 'VB'),
#  ('extra', 'JJ'),
#  ('police', 'NN'),
#  ('officers', 'NNS'),
#  ('to', 'TO'),
#  ('guard', 'VB'),
#  ('houses', 'NNS'),
#  ('of', 'IN'),
#  ('worship.The', 'JJ'),
#  ('nature', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('threat', 'NN'),
#  ('was', 'VBD'),
#  ('vague', 'JJ'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('FBI', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('Newark', 'NNP'),
#  ('office', 'NN'),
#  ('released', 'VBD'),
#  ('a', 'DT'),
#  ('statement', 'NN'),
#  ('urging', 'VBG'),
#  ('synagogues', 'NNS'),
#  ('to', 'TO'),
#  ('“', 'VB'),
#  ('take', 'VB'),
#  ('all', 'DT'),
#  ('security', 'NN'),
#  ('precautions', 'NNS'),
#  ('to', 'TO'),
#  ('protect', 'VB'),
#  ('your', 'PRP$'),
#  ('community', 'NN'),
#  ('and', 'CC'),
#  ('facility', 'NN'),
#  (',', ','),
#  ('”', 'NNP'),
#  ('but', 'CC'),
#  ('wouldn', 'JJ'),
#  ('’', 'JJ'),
#  ('t', 'NNS'),
#  ('say', 'VBP'),
#  ('anything', 'NN'),
#  ('about', 'IN'),
#  ('who', 'WP'),
#  ('made', 'VBD'),
#  ('the', 'DT'),
#  ('threat', 'NN'),
#  ('or', 'CC'),
#  ('why.The', 'NN'),
#  ('alert', 'NN'),
#  ('was', 'VBD'),
#  ('posted', 'VBN'),
#  ('after', 'IN'),
#  ('officials', 'NNS'),
#  ('discovered', 'VBD'),
#  ('an', 'DT'),
#  ('online', 'JJ'),
#  ('threat', 'NN'),
#  ('directed', 'VBD'),
#  ('broadly', 'RB'),
#  ('at', 'IN'),
#  ('synagogues', 'NNS'),
#  ('in', 'IN'),
#  ('New', 'NNP'),
#  ('Jersey', 'NNP'),
#  (',', ','),
#  ('a', 'DT'),
#  ('law', 'NN'),
#  ('enforcement', 'NN'),
#  ('official', 'NN'),
#  ('said', 'VBD'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('posting', 'VBG'),
#  ('did', 'VBD'),
#  ('not', 'RB'),
#  ('target', 'VB'),
#  ('any', 'DT'),
#  ('specific', 'JJ'),
#  ('synagogue', 'NN'),
#  ('by', 'IN'),
#  ('name', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('official', 'NN'),
#  ('said', 'VBD'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('official', 'NN'),
#  ('could', 'MD'),
#  ('not', 'RB'),
#  ('discuss', 'VB'),
#  ('details', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('investigation', 'NN'),
#  ('publicly', 'RB'),
#  ('and', 'CC'),
#  ('spoke', 'VBD'),
#  ('to', 'TO'),
#  ('The', 'DT'),
#  ('Associated', 'NNP'),
#  ('Press', 'NNP'),
#  ('on', 'IN'),
#  ('condition', 'NN'),
#  ('of', 'IN'),
#  ('anonymity.Messages', 'NNS'),
#  ('left', 'VBN'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('FBI', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('Newark', 'NNP'),
#  ('office', 'NN'),
#  ('weren', 'NN'),
#  ('’', 'VBP'),
#  ('t', 'JJ'),
#  ('returned.Public', 'JJ'),
#  ('warnings', 'NNS'),
#  ('about', 'IN'),
#  ('nonspecific', 'JJ'),
#  ('threats', 'NNS'),
#  ('against', 'IN'),
#  ('Jewish', 'JJ'),
#  ('institutions', 'NNS'),
#  (',', ','),
#  ('made', 'VBN'),
#  ('by', 'IN'),
#  ('a', 'DT'),
#  ('variety', 'NN'),
#  ('of', 'IN'),
#  ('groups', 'NNS'),
#  ('including', 'VBG'),
#  ('Christian', 'JJ'),
#  ('supremacists', 'NNS'),
#  ('and', 'CC'),
#  ('Islamist', 'NNP'),
#  ('extremists', 'NNS'),
#  (',', ','),
#  ('aren', 'NNS'),
#  ('’', 'VBP'),
#  ('t', 'JJ'),
#  ('unusual', 'JJ'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('New', 'NNP'),
#  ('York', 'NNP'),
#  ('City', 'NNP'),
#  ('metropolitan', 'JJ'),
#  ('area', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('many', 'JJ'),
#  ('turn', 'VBP'),
#  ('out', 'RP'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('false', 'JJ'),
#  ('alarms', 'NNS'),
#  ('.', '.'),
#  ('But', 'CC'),
#  ('the', 'DT'),
#  ('area', 'NN'),
#  ('has', 'VBZ'),
#  ('also', 'RB'),
#  ('seen', 'VBN'),
#  ('deadly', 'RB'),
#  ('attacks.ADVERTISEMENTIn', 'JJ'),
#  ('Jersey', 'NNP'),
#  ('City', 'NNP'),
#  (',', ','),
#  ('Mayor', 'NNP'),
#  ('Steven', 'NNP'),
#  ('Fulop', 'NNP'),
#  ('said', 'VBD'),
#  ('police', 'NNS'),
#  ('would', 'MD'),
#  ('be', 'VB'),
#  ('posted', 'VBN'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('city', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('seven', 'CD'),
#  ('synagogues', 'NNS'),
#  ('and', 'CC'),
#  ('foot', 'NN'),
#  ('patrols', 'NNS'),
#  ('would', 'MD'),
#  ('be', 'VB'),
#  ('added', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('broader', 'JJR'),
#  ('Jewish', 'NNP'),
#  ('community', 'NN'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('2019', 'CD'),
#  (',', ','),
#  ('two', 'CD'),
#  ('assailants', 'NNS'),
#  ('motivated', 'VBN'),
#  ('by', 'IN'),
#  ('anti-Jewish', 'JJ'),
#  ('hate', 'NN'),
#  ('killed', 'VBD'),
#  ('a', 'DT'),
#  ('police', 'NN'),
#  ('officer', 'NN'),
#  (',', ','),
#  ('then', 'RB'),
#  ('drove', 'VB'),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('kosher', 'NN'),
#  ('market', 'NN'),
#  ('in', 'IN'),
#  ('Jersey', 'NNP'),
#  ('City', 'NNP'),
#  ('and', 'CC'),
#  ('killed', 'VBD'),
#  ('three', 'CD'),
#  ('more', 'JJR'),
#  ('people', 'NNS'),
#  (',', ','),
#  ('before', 'IN'),
#  ('being', 'VBG'),
#  ('slain', 'VBN'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('gunbattle', 'NN'),
#  ('with', 'IN'),
#  ('police.ReligionPope', 'NN'),
#  ('tells', 'NNS'),
#  ('Bahrain', 'VBP'),
#  ('youths', 'NNS'),
#  ('to', 'TO'),
#  ('seek', 'VB'),
#  ('real', 'JJ'),
#  ('advice', 'NN'),
#  (',', ','),
#  ('not', 'RB'),
#  ('GoogleKosovo', 'NNP'),
#  ("'s", 'POS'),
#  ('ethnic', 'JJ'),
#  ('Serb', 'NNP'),
#  ('police', 'NNS'),
#  (',', ','),
#  ('lawmakers', 'NNS'),
#  ('resign', 'VBP'),
#  ('en', 'JJ'),
#  ('masseWalker', 'NN'),
#  (',', ','),
#  ('Warnock', 'NNP'),
#  ('offer', 'VBP'),
#  ('clashing', 'VBG'),
#  ('religious', 'JJ'),
#  ('messages', 'NNS'),
#  ('in', 'IN'),
#  ('GeorgiaPrivate', 'NNP'),
#  ('school', 'NN'),
#  ('vouchers', 'NNS'),
#  ('open', 'VBP'),
#  ('faith', 'NN'),
#  ('options', 'NNS'),
#  ('for', 'IN'),
#  ('kids', 'NNS'),
#  ('of', 'IN'),
#  ('colorPolice', 'NN'),
#  ('officers', 'NNS'),
#  ('armed', 'VBD'),
#  ('with', 'IN'),
#  ('rifles', 'NNS'),
#  ('guarded', 'VBD'),
#  ('a', 'DT'),
#  ('synagogue', 'JJ'),
#  ('one', 'CD'),
#  ('city', 'NN'),
#  ('over', 'IN'),
#  (',', ','),
#  ('in', 'IN'),
#  ('Hoboken', 'NNP'),
#  (',', ','),
#  ('where', 'WRB'),
#  ('the', 'DT'),
#  ('public', 'JJ'),
#  ('safety', 'NN'),
#  ('director', 'NN'),
#  ('also', 'RB'),
#  ('announced', 'VBD'),
#  ('increased', 'JJ'),
#  ('patrols', 'NNS'),
#  ('in', 'IN'),
#  ('Jewish', 'JJ'),
#  ('communities.Five', 'CD'),
#  ('years', 'NNS'),
#  ('ago', 'RB'),
#  (',', ','),
#  ('two', 'CD'),
#  ('New', 'NNP'),
#  ('Jersey', 'NNP'),
#  ('men', 'NNS'),
#  ('were', 'VBD'),
#  ('sentenced', 'VBN'),
#  ('to', 'TO'),
#  ('35', 'CD'),
#  ('years', 'NNS'),
#  ('in', 'IN'),
#  ('prison', 'NN'),
#  ('after', 'IN'),
#  ('being', 'VBG'),
#  ('convicted', 'VBN'),
#  ('for', 'IN'),
#  ('a', 'DT'),
#  ('series', 'NN'),
#  ('of', 'IN'),
#  ('attacks', 'NNS'),
#  ('in', 'IN'),
#  ('2012', 'CD'),
#  ('that', 'WDT'),
#  ('included', 'VBD'),
#  ('the', 'DT'),
#  ('firebombings', 'NNS'),
#  ('of', 'IN'),
#  ('two', 'CD'),
#  ('synagogues', 'NNS'),
#  ('.', '.'),
#  ('They', 'PRP'),
#  ('also', 'RB'),
#  ('threw', 'VBD'),
#  ('a', 'DT'),
#  ('Molotov', 'NNP'),
#  ('cocktail', 'NN'),
#  ('into', 'IN'),
#  ('the', 'DT'),
#  ('home', 'NN'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('rabbi', 'NN'),
#  ('as', 'IN'),
#  ('he', 'PRP'),
#  ('slept', 'VBD'),
#  ('with', 'IN'),
#  ('his', 'PRP$'),
#  ('wife', 'NN'),
#  ('and', 'CC'),
#  ('children.In', 'NN'),
#  ('2019', 'CD'),
#  (',', ','),
#  ('a', 'DT'),
#  ('man', 'NN'),
#  ('stabbed', 'VBD'),
#  ('five', 'CD'),
#  ('people', 'NNS'),
#  ('at', 'IN'),
#  ('a', 'DT'),
#  ('Hanukkah', 'NNP'),
#  ('celebration', 'NN'),
#  ('at', 'IN'),
#  ('a', 'DT'),
#  ('rabbi', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('home', 'NN'),
#  ('in', 'IN'),
#  ('an', 'DT'),
#  ('Orthodox', 'NNP'),
#  ('Jewish', 'NNP'),
#  ('community', 'NN'),
#  ('north', 'NN'),
#  ('of', 'IN'),
#  ('New', 'NNP'),
#  ('York', 'NNP'),
#  ('City', 'NNP'),
#  (',', ','),
#  ('fatally', 'RB'),
#  ('wounding', 'VBG'),
#  ('one', 'CD'),
#  ('person.U.S', 'NN'),
#  ('.', '.'),
#  ('Rep.', 'NNP'),
#  ('Josh', 'NNP'),
#  ('Gottheimer', 'NNP'),
#  (',', ','),
#  ('a', 'DT'),
#  ('New', 'NNP'),
#  ('Jersey', 'NNP'),
#  ('Democrat', 'NNP'),
#  (',', ','),
#  ('said', 'VBD'),
#  ('he', 'PRP'),
#  ('was', 'VBD'),
#  ('“', 'JJ'),
#  ('concerned', 'JJ'),
#  ('and', 'CC'),
#  ('outraged', 'VBN'),
#  ('”', 'NN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('latest', 'JJS'),
#  ('threat', 'NN'),
#  ('against', 'IN'),
#  ('Jews.ADVERTISEMENT', 'NNP'),
#  ('“', 'NNP'),
#  ('I', 'PRP'),
#  ('am', 'VBP'),
#  ('deeply', 'RB'),
#  ('concerned', 'JJ'),
#  ('and', 'CC'),
#  ('outraged', 'VBN'),
#  ('by', 'IN'),
#  ('today', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'NN'),
#  ('alert', 'NN'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('FBI', 'NNP'),
#  (',', ','),
#  ('”', 'NNP'),
#  ('Gottheimer', 'NNP'),
#  ('said', 'VBD'),
#  ('.', '.'),
#  ('“', 'NN'),
#  ('This', 'DT'),
#  ('is', 'VBZ'),
#  ('what', 'WP'),
#  ('happens', 'VBZ'),
#  ('after', 'IN'),
#  ('years', 'NNS'),
#  ('of', 'IN'),
#  ('antisemitic', 'JJ'),
#  ('comments', 'NNS'),
#  ('from', 'IN'),
#  ('public', 'JJ'),
#  ('figures', 'NNS'),
#  (',', ','),
#  ('”', 'CC'),
#  ('he', 'PRP'),
#  ('added', 'VBD'),
#  (',', ','),
#  ('citing', 'VBG'),
#  ('recent', 'JJ'),
#  ('comments', 'NNS'),
#  ('by', 'IN'),
#  ('Kanye', 'NNP'),
#  ('West', 'NNP'),
#  ('and', 'CC'),
#  ('a', 'DT'),
#  ('social', 'JJ'),
#  ('media', 'NNS'),
#  ('post', 'NN'),
#  ('shared', 'VBN'),
#  ('by', 'IN'),
#  ('NBA', 'NNP'),
#  ('star', 'NN'),
#  ('Kyrie', 'NNP'),
#  ('Irving.The', 'NNP'),
#  ('FBI', 'NNP'),
#  ('didn', 'NN'),
#  ('’', 'NNP'),
#  ('t', 'NN'),
#  ('release', 'NN'),
#  ('any', 'DT'),
#  ('information', 'NN'),
#  ('suggesting', 'VBG'),
#  ('the', 'DT'),
#  ('threat', 'NN'),
#  ('that', 'WDT'),
#  ('prompted', 'VBD'),
#  ('the', 'DT'),
#  ('warning', 'NN'),
#  ('was', 'VBD'),
#  ('related', 'VBN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('public', 'JJ'),
#  ('debate', 'NN'),
#  ('over', 'IN'),
#  ('those', 'DT'),
#  ('comments.___Balsamo', 'NNS'),
#  ('reported', 'VBN'),
#  ('from', 'IN'),
#  ('Washington', 'NNP'),
#  ('.', '.'),
#  ('Associated', 'NNP'),
#  ('Press', 'NNP'),
#  ('writer', 'NN'),
#  ('David', 'NNP'),
#  ('Porter', 'NNP'),
#  ('contributed', 'VBD'),
#  ('to', 'TO'),
#  ('this', 'DT'),
#  ('report.AP', 'NN'),
#  ('NEWSTop', 'NNP'),
#  ('StoriesVideoContact', 'NNP'),
#  ('UsAccessibility', 'NNP'),
#  ('StatementCookie', 'NNP'),
#  ('SettingsDownload', 'NNP'),
#  ('AP', 'NNP'),
#  ('NEWSConnect', 'NNP'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('definitive', 'JJ'),
#  ('source', 'NN'),
#  ('for', 'IN'),
#  ('global', 'JJ'),
#  ('and', 'CC'),
#  ('local', 'JJ'),
#  ('newsMore', 'NN'),
#  ('from', 'IN'),
#  ('APap.orgAP', 'NNP'),
#  ('InsightsAP', 'NNP'),
#  ('Definitive', 'NNP'),
#  ('Source', 'NNP'),
#  ('BlogAP', 'NNP'),
#  ('Images', 'NNP'),
#  ('SpotlightAP', 'NNP'),
#  ('ExploreAP', 'NNP'),
#  ('BooksAP', 'NNP'),
#  ('StylebookFollow', 'NNP'),
#  ('APThe', 'NNP'),
#  ('Associated', 'NNP'),
#  ('PressAboutContactCustomer', 'NNP'),
#  ('SupportCareersTerms', 'NNP'),
#  ('&', 'CC'),
#  ('ConditionsPrivacyAll', 'NNP'),
#  ('contents', 'VBZ'),
#  ('©', 'VB'),
#  ('copyright', 'JJ'),
#  ('2022', 'CD'),
#  ('The', 'DT'),
#  ('Associated', 'NNP'),
#  ('Press', 'NNP'),
#  ('.', '.'),
#  ('All', 'NNP'),
#  ('rights', 'NNS'),
#  ('reserved', 'VBN'),
#  ('.', '.')]

# %%
document = '1 December 2021, the FARDC fought back at Goma and recaptured a position from M23 militia. The MONUSCO supplied their advances. Start was given to the operation!'

# %%
document = document.lower()
document
# Out:
# '1 december 2021, the fardc fought back at goma and recaptured a position from m23 militia. the monusco supplied their advances. start was given to the operation!'

# %%
{(' '.join(c[0] for c in chunk), chunk.label() ) for chunk in nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(document))) if hasattr(chunk, 'label') }
# Out:
# set()

# %% [markdown]
# # spacy

# %%
# !pip install spacy
# !python -m spacy validate

# %%
import spacy
from spacy import displacy 
import en_core_web_sm

# %%
document = '1 December 2021, the FARDC fought back near Goma and recaptured a position from M23 militia. The MONUSCO supplied their advances. Start was given to the operation! As said the representative of the red cross, "kaboom!". unhcr confirmed the news. Monika allocated the assets near komanda village. floribert said that he was in the car. Sputnik news agency was on the spot. Kinshasa welcomed the delegation. In Kinshasa the delegation was welcomed by the minister. CCTV covered the incident while un people protested. Mai-Mai Yakutumba attacked Nyamilima. Mai-Mai Raia Mutomboki surrendered on Friday. UPC collected 10000 francs to participate in the elections next year. New Technoligies is going to import coltan from Katanga. The President Tchisekedi rejected their claims. Major Solana confirmed the crash of a helicopter near Kabalo. 300000 IDPs were registered in Kongolo. Twenty Twa were killed in the massacre. The conflict between Batende and Banunu tribes disrupted the elections in Mai-Ndombe province. Fifty people drowned in Ubangi river. Fifty people drowned in the Congo River last weekends. Gazprom refused to import fertolizers. CAID statistic was very important for the article of Kanakake Kagame. air france stopped all flights next week. ADF combatants are going to take part in the DDRRR process. FDLR militiamen escaped an FARDC ambush. Putin is dead. Obama wants coca-cola. France24 covered the story. Loran Nkunda escaped to Rwanda. Nyiragongo erupted in Virunga park. General Baka resigned. MM Yakutumba refused to negotiate. The PNC said it was not their business. ANR spokesperson Trafaret Kirzun announced new operation. Gallery Presidentielle Ancienne hosts the mission. Saint Petersburg was visited by Madonna. Manila under attack! Mai-Mai Malaika captured Kabambare.'

# %%
# document = url_to_string('https://apnews.com/article/new-jersey-newark-city-113055436513a7ac0f1d875cd5913e01?utm_source=homepage&utm_medium=TopNews&utm_campaign=position_04')

# %%
nlp = en_core_web_sm.load()
ny_bb = document
article = nlp(ny_bb)
displacy.render(article, jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1 December 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FARDC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  fought back near
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Goma
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and recaptured a position from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     M23 militia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . The MONUSCO supplied their advances. Start was given to the operation! As said the representative of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the red cross
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , &quot;kaboom!&quot;.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     unhcr
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  confirmed the news. Monika allocated the assets near
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     komanda village
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     floribert
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said that he was in the car. Sputnik news agency was on the spot.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kinshasa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  welcomed the delegation. In
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kinshasa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  the delegation was welcomed by the minister.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CCTV
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  covered the incident while
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     un
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  people protested.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mai-Mai Yakutumba
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  attacked
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nyamilima
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mai-Mai Raia Mutomboki
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  surrendered on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     UPC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  collected
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10000 francs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  to participate in the elections
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     next year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New Technoligies
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is going to import coltan from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Katanga
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . The President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tchisekedi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  rejected their claims. Major
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Solana
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  confirmed the crash of a helicopter near
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kabalo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</s

# %%
article
# Out:
# 1 December 2021, the FARDC fought back near Goma and recaptured a position from M23 militia. The MONUSCO supplied their advances. Start was given to the operation! As said the representative of the red cross, "kaboom!". unhcr confirmed the news. Monika allocated the assets near komanda village. floribert said that he was in the car. Sputnik news agency was on the spot. Kinshasa welcomed the delegation. In Kinshasa the delegation was welcomed by the minister. CCTV covered the incident while un people protested. Mai-Mai Yakutumba attacked Nyamilima. Mai-Mai Raia Mutomboki surrendered on Friday. UPC collected 10000 francs to participate in the elections next year. New Technoligies is going to import coltan from Katanga. The President Tchisekedi rejected their claims. Major Solana confirmed the crash of a helicopter near Kabalo. 300000 IDPs were registered in Kongolo. Twenty Twa were killed in the massacre. The conflict between Batende and Banunu tribes disrupted the elections in Mai-Ndombe province. Fifty people drowned in Ubangi river. Fifty people drowned in the Congo River last weekends. Gazprom refused to import fertolizers. CAID statistic was very important for the article of Kanakake Kagame. air france stopped all flights next week. ADF combatants are going to take part in the DDRRR process. FDLR militiamen escaped an FARDC ambush. Putin is dead. Obama wants coca-cola. France24 covered the story. Loran Nkunda escaped to Rwanda. Nyiragongo erupted in Virunga park. General Baka resigned. MM Yakutumba refused to negotiate. The PNC said it was not their business. ANR spokesperson Trafaret Kirzun announced new operation. Gallery Presidentielle Ancienne hosts the mission. Saint Petersburg was visited by Madonna. Manila under attack! Mai-Mai Malaika captured Kabambare.

# %%
type(article)
# Out:
# spacy.tokens.doc.Doc

# %%
nlp.pipe_names
# Out:
# ['tok2vec',
#  'tagger',
#  'parser',
#  'senter',
#  'attribute_ruler',
#  'lemmatizer',
#  'ner']

# %%
article.ents
# Out:
# (1 December 2021,
#  FARDC,
#  Goma,
#  M23 militia,
#  the red cross,
#  unhcr,
#  komanda village,
#  floribert,
#  Kinshasa,
#  Kinshasa,
#  CCTV,
#  un,
#  Mai-Mai Yakutumba,
#  Nyamilima,
#  Mai-Mai Raia Mutomboki,
#  Friday,
#  UPC,
#  10000 francs,
#  next year,
#  New Technoligies,
#  Katanga,
#  Tchisekedi,
#  Solana,
#  Kabalo,
#  300000,
#  Kongolo,
#  Twenty,
#  Batende,
#  Banunu,
#  Mai-Ndombe,
#  Fifty,
#  Ubangi,
#  Fifty,
#  the Congo River,
#  last weekends,
#  CAID,
#  Kanakake Kagame,
#  air france,
#  next week,
#  DDRRR,
#  FDLR,
#  FARDC,
#  Putin,
#  Obama,
#  coca-cola,
#  Loran Nkunda,
#  Rwanda,
#  Nyiragongo,
#  Virunga,
#  Baka,
#  MM Yakutumba,
#  PNC,
#  ANR,
#  Trafaret Kirzun,
#  Presidentielle Ancienne,
#  Saint Petersburg,
#  Madonna,
#  Manila,
#  Mai-Mai Malaika,
#  Kabambare)

# %%
[(_.text, _.label_) for _ in article.ents]
# Out:
# [('1 December 2021', 'DATE'),
#  ('FARDC', 'ORG'),
#  ('Goma', 'PERSON'),
#  ('M23 militia', 'ORG'),
#  ('the red cross', 'ORG'),
#  ('unhcr', 'ORG'),
#  ('komanda village', 'GPE'),
#  ('floribert', 'PERSON'),
#  ('Kinshasa', 'ORG'),
#  ('Kinshasa', 'GPE'),
#  ('CCTV', 'ORG'),
#  ('un', 'ORG'),
#  ('Mai-Mai Yakutumba', 'ORG'),
#  ('Nyamilima', 'GPE'),
#  ('Mai-Mai Raia Mutomboki', 'PERSON'),
#  ('Friday', 'DATE'),
#  ('UPC', 'ORG'),
#  ('10000 francs', 'MONEY'),
#  ('next year', 'DATE'),
#  ('New Technoligies', 'ORG'),
#  ('Katanga', 'GPE'),
#  ('Tchisekedi', 'PERSON'),
#  ('Solana', 'PERSON'),
#  ('Kabalo', 'GPE'),
#  ('300000', 'CARDINAL'),
#  ('Kongolo', 'GPE'),
#  ('Twenty', 'CARDINAL'),
#  ('Batende', 'ORG'),
#  ('Banunu', 'ORG'),
#  ('Mai-Ndombe', 'LOC'),
#  ('Fifty', 'CARDINAL'),
#  ('Ubangi', 'ORG'),
#  ('Fifty', 'CARDINAL'),
#  ('the Congo River', 'LOC'),
#  ('last weekends', 'DATE'),
#  ('CAID', 'ORG'),
#  ('Kanakake Kagame', 'PERSON'),
#  ('air france', 'ORG'),
#  ('next week', 'DATE'),
#  ('DDRRR', 'ORG'),
#  ('FDLR', 'ORG'),
#  ('FARDC', 'ORG'),
#  ('Putin', 'PERSON'),
#  ('Obama', 'PERSON'),
#  ('coca-cola', 'ORG'),
#  ('Loran Nkunda', 'PERSON'),
#  ('Rwanda', 'GPE'),
#  ('Nyiragongo', 'GPE'),
#  ('Virunga', 'GPE'),
#  ('Baka', 'PERSON'),
#  ('MM Yakutumba', 'PERSON'),
#  ('PNC', 'ORG'),
#  ('ANR', 'ORG'),
#  ('Trafaret Kirzun', 'PERSON'),
#  ('Presidentielle Ancienne', 'PERSON'),
#  ('Saint Petersburg', 'PERSON'),
#  ('Madonna', 'PERSON'),
#  ('Manila', 'GPE'),
#  ('Mai-Mai Malaika', 'ORG'),
#  ('Kabambare', 'ORG')]

# %%
# GPE - Geopolitical entity, i.e. countries, cities, states.

# %% [markdown]
# ### spacy NER in French

# %%
# !python -m spacy download fr_core_news_sm

# %%
import fr_core_news_sm

# %%
document = "Une personne a été tuée par balles et cinq autres enlevées dans la nuit de lundi à mardi 26 avril lors d’une embuscade armée près du village d’Etchibe situé à 16 km au sud de la ville de Baraka (Sud-Kivu). En effet, un groupe de sept combattants présumés de Maï-Maï Yakutumba avait fait une intrusion dans trois maisons locales à Misisi-Centre vers 23h (21h TU). Dépêchée sur le lieu, la patrouille mixte FARDC-PNC a réussi à capturer l'un des auteurs avec son arme. Tandis que d'autres criminels ont réussi à s'échapper sans être remarqués. D'autres sources indiquent que le même groupe de criminels a enlevé cinq civils à bord d'un véhicule privé. Informé de cette situation, le commandant du 2202e régiment des FARDC, le colonel David Ipanga, dit avoir dépêché une patrouille de combat dans la zone touchée. Cependant, aucun autre détail n'a été fourni. Pour l’instant, des sources sécuritaires à Misisi signalent que le coupable est détenu par les FARDC pour un nouvel interrogatoire et une procédure judiciaire."

# %%
nlp = fr_core_news_sm.load()
ny_bb = document
article = nlp(ny_bb)
displacy.render(article, jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Une personne a été tuée par balles et cinq autres enlevées dans la nuit de lundi à mardi 26 avril lors d’une embuscade armée près du village d’
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Etchibe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  situé à 16 km au sud de la ville de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Baraka
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  (
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sud-Kivu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ). En effet, un groupe de sept combattants présumés de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Maï-Maï Yakutumba
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  avait fait une intrusion dans trois maisons locales à
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Misisi-Centre
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  vers 23h (21h TU). Dépêchée sur le lieu, la patrouille mixte FARDC-PNC a réussi à capturer l'un des auteurs avec son arme. Tandis que d'autres criminels ont réussi à s'échapper sans être remarqués. D'autres sources indiquent que le même groupe de criminels a enlevé cinq civils à bord d'un véhicule privé. Informé de cette situation, le commandant du 2202e régiment des FARDC, le colonel
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     David Ipanga
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , dit avoir dépêché une patrouille de combat dans la zone touchée. Cependant, aucun autre détail n'a été fourni. Pour l’instant, des sources sécuritaires à
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Misisi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  signalent que le coupable est détenu par les
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FARDC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  pour un nouvel interrogatoire et une procédure judiciaire.</div></span>

# %% [markdown]
# ## There are better models https://spacy.io/models/fr with a better performance!!!

# %% [markdown]
# https://www.youtube.com/watch?v=2XUhKpH0p4M

# %%
import spacy
import en_core_web_sm

# %%
document = "Tesla Inc is going to aquire twitter for $45 billion"

nlp = en_core_web_sm.load()
document_processed = nlp(document)

# %%
type(document_processed)
# Out:
# spacy.tokens.doc.Doc

# %%
document_processed.ents
# Out:
# (Tesla Inc, $45 billion)

# %%
document_processed.ents[0]
# Out:
# Tesla Inc

# %%
document_processed.ents[0].text
# Out:
# 'Tesla Inc'

# %%
document_processed.ents[0].label_
# Out:
# 'ORG'

# %%
spacy.explain(document_processed.ents[0].label_)
# Out:
# 'Companies, agencies, institutions, etc.'

# %%
for entity in document_processed.ents:
    print(entity.text, '|', entity.label_, '|', spacy.explain(entity.label_))
# Out:
# Tesla Inc | ORG | Companies, agencies, institutions, etc.
# $45 billion | MONEY | Monetary values, including unit

# %%
from spacy import displacy 

displacy.render(document_processed, jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla Inc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is going to aquire twitter for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $45 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </div></span>

# %% [markdown]
# twitter was not recognized, let's capitalize it

# %%
document = "Tesla Inc is going to aquire Twitter for $45 billion"

nlp = en_core_web_sm.load()
document_processed = nlp(document)

# %%
displacy.render(document_processed, jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla Inc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is going to aquire
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $45 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </div></span>

# %%
document = "moscow was founded in 988 bc"

nlp = en_core_web_sm.load()
document_processed = nlp(document)

# %%
displacy.render(document_processed, jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     moscow
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  was founded in
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     988
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  bc</div></span>

# %%
for entity in document_processed.ents:
    print(entity.text, '|', entity.label_, '|', spacy.explain(entity.label_))
# Out:
# moscow | GPE | Countries, cities, states
# 988 | CARDINAL | Numerals that do not fall under another type

# %%
type(document_processed)
# Out:
# spacy.tokens.doc.Doc

# %%
type(document_processed[0])
# Out:
# spacy.tokens.token.Token

# %%
document_processed[1:]
# Out:
# was founded in 988 bc

# %% [markdown]
# # transformers

# %% [markdown]
# https://huggingface.co/dslim/bert-base-NER?text=My+name+is+Clara+and+I+live+in+Berkeley%2C+California.

# %% [markdown]
# bert-base-NER is a fine-tuned BERT model that is ready to use for Named Entity Recognition and achieves state-of-the-art performance for the NER task. It has been trained to recognize four types of entities: location (LOC), organizations (ORG), person (PER) and Miscellaneous (MISC).

# %%
# !pip install transformers

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

tokenizer = AutoTokenizer.from_pretrained("dslim/bert-base-NER")
model = AutoModelForTokenClassification.from_pretrained("dslim/bert-base-NER")
nlp = pipeline("ner", model=model, tokenizer=tokenizer)

# %%
example = "My name is Wolfgang and I live in Berlin"

ner_results = nlp(example)
print(ner_results)
# Out:
# [{'entity': 'B-PER', 'score': 0.9990139, 'index': 4, 'word': 'Wolfgang', 'start': 11, 'end': 19}, {'entity': 'B-LOC', 'score': 0.999645, 'index': 9, 'word': 'Berlin', 'start': 34, 'end': 40}]

# %%
example = "Luis and Alice were killed in Blumenau"

ner_results = nlp(example)
print(ner_results)
# Out:
# [{'entity': 'B-PER', 'score': 0.9992606, 'index': 1, 'word': 'Luis', 'start': 0, 'end': 4}, {'entity': 'B-PER', 'score': 0.9975923, 'index': 3, 'word': 'Alice', 'start': 9, 'end': 14}, {'entity': 'B-LOC', 'score': 0.9946719, 'index': 7, 'word': 'Blu', 'start': 30, 'end': 33}, {'entity': 'I-LOC', 'score': 0.99243355, 'index': 8, 'word': '##men', 'start': 33, 'end': 36}, {'entity': 'I-LOC', 'score': 0.75294447, 'index': 9, 'word': '##au', 'start': 36, 'end': 38}]

# %%
ner_results[2:]  # Blumenau
# Out:
# [{'entity': 'B-LOC',
#   'score': 0.9946719,
#   'index': 7,
#   'word': 'Blu',
#   'start': 30,
#   'end': 33},
#  {'entity': 'I-LOC',
#   'score': 0.99243355,
#   'index': 8,
#   'word': '##men',
#   'start': 33,
#   'end': 36},
#  {'entity': 'I-LOC',
#   'score': 0.75294447,
#   'index': 9,
#   'word': '##au',
#   'start': 36,
#   'end': 38}]

# %%
example = "My name is Evgenii, and I live in Saint Petersburg"

ner_results = nlp(example)
print(ner_results)
# Out:
# [{'entity': 'B-PER', 'score': 0.9828704, 'index': 4, 'word': 'E', 'start': 11, 'end': 12}, {'entity': 'B-PER', 'score': 0.68019027, 'index': 5, 'word': '##v', 'start': 12, 'end': 13}, {'entity': 'B-PER', 'score': 0.8987502, 'index': 6, 'word': '##gen', 'start': 13, 'end': 16}, {'entity': 'B-PER', 'score': 0.5416685, 'index': 7, 'word': '##ii', 'start': 16, 'end': 18}, {'entity': 'B-LOC', 'score': 0.9991812, 'index': 13, 'word': 'Saint', 'start': 34, 'end': 39}, {'entity': 'I-LOC', 'score': 0.9991375, 'index': 14, 'word': 'Petersburg', 'start': 40, 'end': 50}]

# %%
ner_results[:4]  # Evgenii
# Out:
# [{'entity': 'B-PER',
#   'score': 0.9828704,
#   'index': 4,
#   'word': 'E',
#   'start': 11,
#   'end': 12},
#  {'entity': 'B-PER',
#   'score': 0.68019027,
#   'index': 5,
#   'word': '##v',
#   'start': 12,
#   'end': 13},
#  {'entity': 'B-PER',
#   'score': 0.8987502,
#   'index': 6,
#   'word': '##gen',
#   'start': 13,
#   'end': 16},
#  {'entity': 'B-PER',
#   'score': 0.5416685,
#   'index': 7,
#   'word': '##ii',
#   'start': 16,
#   'end': 18}]

# %%
example = "Nikola Tesla"

ner_results = nlp(example)
print(ner_results)
# Out:
# [{'entity': 'B-PER', 'score': 0.99947244, 'index': 1, 'word': 'Nikola', 'start': 0, 'end': 6}, {'entity': 'I-PER', 'score': 0.99921703, 'index': 2, 'word': 'Te', 'start': 7, 'end': 9}, {'entity': 'I-PER', 'score': 0.9988186, 'index': 3, 'word': '##sla', 'start': 9, 'end': 12}]
